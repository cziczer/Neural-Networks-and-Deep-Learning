# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

# %%
def gaussian(batch, stochastic=False):
#     raise Exception("Gaussian activation function is not implemented")
    if stochastic:
        return np.random.normal(loc=batch, scale=1)
    return batch

def gaussian_derivative(batch):
#     raise Exception("Derivative of the gaussian activation function is not implemented")
    return ones(*batch.shape)
    # return ???

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]

    rbm.W += rbm.M;
    
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size))
    
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].hidden_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    error = reconstuction_error(dbn[layer_idx], propagated)
    return error

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # Autoencoder training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %%
def forward_pass(ae, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(ae):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
        visible = layer.activations

    return visible[:, :-1]

def error_backpropagate(ae, batch):
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch
        
        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (visible.T @ layer.deltas)
        
        if layer.l2_penalty > 0:
            layer.M[:-1, :] = layer.M[:-1, :] - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]
        
        layer.W += layer.M

# %% [markdown]
# ### Cross entropy cost

# %% [markdown]
# Implement cross entropy cost for deep AE. To this end:
# * calculate the cross entropy cost between pixels in the input batch and their reconstructions,
# * sum the cross entropy cost over all pixels and all observations in the minibatch,
# * return average cost per input observation.

# %%
def xentropy(batch, reconstructions):
    observations_count = batch.shape[0]
    return -np.sum(batch * np.log(reconstructions) + (1-batch) * np.log(1-reconstructions)) / observations_count

# %% [markdown]
# ### Training procedure

# %%
def train_ae(ae, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)
    
    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)

        ae[-1].deltas = reconstructions - batch[:,:-1]
        
        error_backpropagate(ae, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_ae_training(ae, train_set, validation_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print("\telapsed: {0:>2.2f}s, cross-entropy: {1:>2.2f}".format(elapsed, xe))

    print("Training finished!")

# %% [markdown]
# ###  Initializing AE with DBN weights
#
# Implement initialization of AE weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the AE weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_ae(ae, dbn):
    assert(len(ae) == 2*len(dbn))
    
    for layer_idx, layer in enumerate(dbn):
        ae[layer_idx].W = np.copy(layer.W[:, :-1])
        
    ae_idx = len(dbn)
    for layer_idx in range(len(dbn)-1, -1,-1):
        ae[ae_idx].W = np.copy(dbn[layer_idx].W[:-1, :].T)
        ae_idx += 1

# %% [markdown]
# # Autoencoder for MNIST digits

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE

BATCH_SIZE = 128
EPOCHS_COUNT = 50

RBM_LEARNING_RATE = 0.1
AE_LEARNING_RATE = 0.01
AE_MOMENTUM = 0.9
L2_PENALTY = 0.0002

# %%
from IPython.core.display import HTML

def compare_results(ae, dbn,
                    train_set, validation_set, monitoring_set,
                    batch_size, epochs_count):
    for layer in ae:
        layer.reset()
    
    display(HTML('<h3>Plain AE training</h3>'))
    run_ae_training(ae, train_set, validation_set,
                    batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain AE</h3>'))
    draw_layer_filters(ae[0])
    
    display(HTML('<h3>Input minibatch</h3>'))
    tiles(np.reshape(validation_set[:8*24, :-1],
                     newshape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Plain AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False),
                                    newshape=(8, 24, 28, 28))
    tiles(ae_reconstructions)
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in ae:
        layer.reset()
    
    initialize_ae(ae, dbn)
    dbn_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24, :], False),
                                     newshape=(8, 24, 28, 28))
    dbn_rec_cost = xentropy(validation_set[:, :-1],
                            forward_pass(ae, validation_set, False))
    
    display(HTML('<h3>Finetuning pretrained AE</h3>'))
    
    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(ae, train_set, validation_set,
                    batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned AE</h3>'))
    draw_layer_filters(ae[0])
    
    display(HTML('<h3>Input minibatch</h3>'))
    tiles(np.reshape(validation_set[:8*24, :-1],
                     newshape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Pretrained AE reconstructions</h3>'))
    tiles(dbn_reconstructions)
    
    display(HTML('<h3>Finetuned AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False),
                                    newshape=(8, 24, 28, 28))
    tiles(ae_reconstructions)

# %% [markdown]
# ###  Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]


# raise Exception("AE structure is undefined!")
ae =  [
    Layer(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 10, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(10, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, VISIBLE_LAYER_SIZE, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY)
]

compare_results(ae, dbn,
                mnist_train_images, mnist_test_images,
                monitoring_set,
                BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain AE training</h3>
# Epoch 1:	########################################	elapsed: 0.64s, cross-entropy: 206.27
# Epoch 2:	########################################	elapsed: 0.62s, cross-entropy: 206.18
# Epoch 3:	########################################	elapsed: 0.61s, cross-entropy: 206.16
# Epoch 4:	########################################	elapsed: 0.68s, cross-entropy: 206.15
# Epoch 5:	########################################	elapsed: 0.71s, cross-entropy: 206.14
# Epoch 6:	########################################	elapsed: 0.81s, cross-entropy: 206.14
# Epoch 7:	########################################	elapsed: 0.64s, cross-entropy: 206.13
# Epoch 8:	########################################	elapsed: 0.60s, cross-entropy: 206.12
# Epoch 9:	########################################	elapsed: 0.61s, cross-entropy: 206.12
# Epoch 10:	########################################	elapsed: 0.57s, cross-entropy: 206.11
# Epoch 11:	########################################	elapsed: 0.59s, cross-entropy: 206.11
# Epoch 12:	########################################	elapsed: 0.59s, cross-entropy: 206.10
# Epoch 13:	########################################	elapsed: 0.62s, cross-entropy: 206.10
# Epoch 14:	########################################	elapsed: 0.67s, cross-entropy: 206.10
# Epoch 15:	########################################	elapsed: 0.60s, cross-entropy: 206.09
# Epoch 16:	########################################	elapsed: 0.60s, cross-entropy: 206.09
# Epoch 17:	########################################	elapsed: 0.59s, cross-entropy: 206.08
# Epoch 18:	########################################	elapsed: 0.62s, cross-entropy: 206.08
# Epoch 19:	########################################	elapsed: 0.73s, cross-entropy: 206.08
# Epoch 20:	########################################	elapsed: 0.70s, cross-entropy: 206.07
# Epoch 21:	########################################	elapsed: 0.68s, cross-entropy: 206.07
# Epoch 22:	########################################	elapsed: 0.67s, cross-entropy: 206.07
# Epoch 23:	########################################	elapsed: 0.63s, cross-entropy: 206.07
# Epoch 24:	########################################	elapsed: 0.68s, cross-entropy: 206.06
# Epoch 25:	########################################	elapsed: 0.62s, cross-entropy: 206.06
# Epoch 26:	########################################	elapsed: 0.61s, cross-entropy: 206.06
# Epoch 27:	########################################	elapsed: 0.62s, cross-entropy: 206.06
# Epoch 28:	########################################	elapsed: 0.62s, cross-entropy: 206.05
# Epoch 29:	########################################	elapsed: 0.60s, cross-entropy: 206.05
# Epoch 30:	########################################	elapsed: 0.63s, cross-entropy: 206.05
# Epoch 31:	########################################	elapsed: 0.63s, cross-entropy: 206.05
# Epoch 32:	########################################	elapsed: 0.59s, cross-entropy: 206.04
# Epoch 33:	########################################	elapsed: 0.61s, cross-entropy: 206.04
# Epoch 34:	########################################	elapsed: 0.64s, cross-entropy: 206.04
# Epoch 35:	########################################	elapsed: 0.63s, cross-entropy: 206.04
# Epoch 36:	########################################	elapsed: 0.59s, cross-entropy: 206.04
# Epoch 37:	########################################	elapsed: 0.60s, cross-entropy: 206.03
# Epoch 38:	########################################	elapsed: 0.62s, cross-entropy: 206.03
# Epoch 39:	########################################	elapsed: 0.63s, cross-entropy: 206.03
# Epoch 40:	########################################	elapsed: 0.62s, cross-entropy: 206.03
# Epoch 41:	########################################	elapsed: 0.61s, cross-entropy: 206.03
# Epoch 42:	########################################	elapsed: 0.60s, cross-entropy: 206.03
# Epoch 43:	########################################	elapsed: 0.64s, cross-entropy: 206.02
# Epoch 44:	########################################	elapsed: 0.66s, cross-entropy: 206.02
# Epoch 45:	########################################	elapsed: 0.66s, cross-entropy: 206.02
# Epoch 46:	########################################	elapsed: 0.64s, cross-entropy: 206.02
# Epoch 47:	########################################	elapsed: 0.64s, cross-entropy: 206.02
# Epoch 48:	########################################	elapsed: 0.62s, cross-entropy: 206.02
# Epoch 49:	########################################	elapsed: 0.69s, cross-entropy: 206.01
# Epoch 50:	########################################	elapsed: 0.61s, cross-entropy: 206.01
# Training finished!
# <h3>Input layer filters in the plain AE</h3>
# <h3>Input minibatch</h3>
# <h3>Plain AE reconstructions</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.46s, reconstruction error: 31.57
# Epoch 2:	########################################	elapsed: 0.44s, reconstruction error: 24.97
# Epoch 3:	########################################	elapsed: 0.44s, reconstruction error: 21.26
# Epoch 4:	########################################	elapsed: 0.44s, reconstruction error: 19.21
# Epoch 5:	########################################	elapsed: 0.45s, reconstruction error: 17.92
# Epoch 6:	########################################	elapsed: 0.43s, reconstruction error: 15.50
# Epoch 7:	########################################	elapsed: 0.47s, reconstruction error: 13.72
# Epoch 8:	########################################	elapsed: 0.44s, reconstruction error: 12.45
# Epoch 9:	########################################	elapsed: 0.43s, reconstruction error: 11.86
# Epoch 10:	########################################	elapsed: 0.45s, reconstruction error: 11.37
# Epoch 11:	########################################	elapsed: 0.45s, reconstruction error: 11.01
# Epoch 12:	########################################	elapsed: 0.44s, reconstruction error: 10.86
# Epoch 13:	########################################	elapsed: 0.44s, reconstruction error: 10.62
# Epoch 14:	########################################	elapsed: 0.46s, reconstruction error: 10.35
# Epoch 15:	########################################	elapsed: 0.44s, reconstruction error: 10.22
# Epoch 16:	########################################	elapsed: 0.44s, reconstruction error: 10.00
# Epoch 17:	########################################	elapsed: 0.46s, reconstruction error: 9.94
# Epoch 18:	########################################	elapsed: 0.45s, reconstruction error: 9.80
# Epoch 19:	########################################	elapsed: 0.42s, reconstruction error: 9.71
# Epoch 20:	########################################	elapsed: 0.44s, reconstruction error: 9.73
# Epoch 21:	########################################	elapsed: 0.46s, reconstruction error: 9.73
# Epoch 22:	########################################	elapsed: 0.43s, reconstruction error: 9.58
# Epoch 23:	########################################	elapsed: 0.44s, reconstruction error: 9.66
# Epoch 24:	########################################	elapsed: 0.44s, reconstruction error: 9.30
# Epoch 25:	########################################	elapsed: 0.46s, reconstruction error: 9.36
# Epoch 26:	########################################	elapsed: 0.45s, reconstruction error: 9.15
# Epoch 27:	########################################	elapsed: 0.43s, reconstruction error: 9.34
# Epoch 28:	########################################	elapsed: 0.46s, reconstruction error: 9.21
# Epoch 29:	########################################	elapsed: 0.44s, reconstruction error: 9.23
# Epoch 30:	########################################	elapsed: 0.44s, reconstruction error: 9.14
# Epoch 31:	########################################	elapsed: 0.45s, reconstruction error: 9.25
# Epoch 32:	########################################	elapsed: 0.45s, reconstruction error: 9.18
# Epoch 33:	########################################	elapsed: 0.50s, reconstruction error: 9.06
# Epoch 34:	########################################	elapsed: 0.51s, reconstruction error: 9.15
# Epoch 35:	########################################	elapsed: 0.55s, reconstruction error: 9.07
# Epoch 36:	########################################	elapsed: 0.52s, reconstruction error: 9.01
# Epoch 37:	########################################	elapsed: 0.51s, reconstruction error: 8.91
# Epoch 38:	########################################	elapsed: 0.49s, reconstruction error: 9.01
# Epoch 39:	########################################	elapsed: 0.45s, reconstruction error: 8.93
# Epoch 40:	########################################	elapsed: 0.48s, reconstruction error: 8.95
# Epoch 41:	########################################	elapsed: 0.44s, reconstruction error: 8.90
# Epoch 42:	########################################	elapsed: 0.44s, reconstruction error: 9.03
# Epoch 43:	########################################	elapsed: 0.45s, reconstruction error: 8.80
# Epoch 44:	########################################	elapsed: 0.46s, reconstruction error: 8.88
# Epoch 45:	########################################	elapsed: 0.44s, reconstruction error: 8.89
# Epoch 46:	########################################	elapsed: 0.45s, reconstruction error: 8.62
# Epoch 47:	########################################	elapsed: 0.45s, reconstruction error: 8.84
# Epoch 48:	########################################	elapsed: 0.45s, reconstruction error: 8.79
# Epoch 49:	########################################	elapsed: 0.47s, reconstruction error: 8.68
# Epoch 50:	########################################	elapsed: 0.46s, reconstruction error: 8.70
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.18s, reconstruction error: 20.15
# Epoch 2:	########################################	elapsed: 0.18s, reconstruction error: 15.77
# Epoch 3:	########################################	elapsed: 0.19s, reconstruction error: 13.65
# Epoch 4:	########################################	elapsed: 0.19s, reconstruction error: 12.15
# Epoch 5:	########################################	elapsed: 0.20s, reconstruction error: 11.26
# Epoch 6:	########################################	elapsed: 0.19s, reconstruction error: 9.44
# Epoch 7:	########################################	elapsed: 0.19s, reconstruction error: 8.35
# Epoch 8:	########################################	elapsed: 0.19s, reconstruction error: 7.61
# Epoch 9:	########################################	elapsed: 0.17s, reconstruction error: 7.21
# Epoch 10:	########################################	elapsed: 0.19s, reconstruction error: 7.01
# Epoch 11:	########################################	elapsed: 0.21s, reconstruction error: 6.74
# Epoch 12:	########################################	elapsed: 0.19s, reconstruction error: 6.53
# Epoch 13:	########################################	elapsed: 0.20s, reconstruction error: 6.44
# Epoch 14:	########################################	elapsed: 0.21s, reconstruction error: 6.31
# Epoch 15:	########################################	elapsed: 0.20s, reconstruction error: 6.11
# Epoch 16:	########################################	elapsed: 0.19s, reconstruction error: 6.03
# Epoch 17:	########################################	elapsed: 0.19s, reconstruction error: 6.01
# Epoch 18:	########################################	elapsed: 0.19s, reconstruction error: 5.96
# Epoch 19:	########################################	elapsed: 0.20s, reconstruction error: 5.79
# Epoch 20:	########################################	elapsed: 0.20s, reconstruction error: 5.83
# Epoch 21:	########################################	elapsed: 0.20s, reconstruction error: 5.76
# Epoch 22:	########################################	elapsed: 0.20s, reconstruction error: 5.72
# Epoch 23:	########################################	elapsed: 0.20s, reconstruction error: 5.56
# Epoch 24:	########################################	elapsed: 0.19s, reconstruction error: 5.60
# Epoch 25:	########################################	elapsed: 0.19s, reconstruction error: 5.47
# Epoch 26:	########################################	elapsed: 0.20s, reconstruction error: 5.60
# Epoch 27:	########################################	elapsed: 0.19s, reconstruction error: 5.43
# Epoch 28:	########################################	elapsed: 0.19s, reconstruction error: 5.44
# Epoch 29:	########################################	elapsed: 0.19s, reconstruction error: 5.43
# Epoch 30:	########################################	elapsed: 0.20s, reconstruction error: 5.41
# Epoch 31:	########################################	elapsed: 0.20s, reconstruction error: 5.48
# Epoch 32:	########################################	elapsed: 0.18s, reconstruction error: 5.39
# Epoch 33:	########################################	elapsed: 0.19s, reconstruction error: 5.28
# Epoch 34:	########################################	elapsed: 0.19s, reconstruction error: 5.34
# Epoch 35:	########################################	elapsed: 0.19s, reconstruction error: 5.35
# Epoch 36:	########################################	elapsed: 0.19s, reconstruction error: 5.26
# Epoch 37:	########################################	elapsed: 0.19s, reconstruction error: 5.26
# Epoch 38:	########################################	elapsed: 0.19s, reconstruction error: 5.23
# Epoch 39:	########################################	elapsed: 0.18s, reconstruction error: 5.22
# Epoch 40:	########################################	elapsed: 0.19s, reconstruction error: 5.20
# Epoch 41:	########################################	elapsed: 0.19s, reconstruction error: 5.16
# Epoch 42:	########################################	elapsed: 0.19s, reconstruction error: 5.10
# Epoch 43:	########################################	elapsed: 0.19s, reconstruction error: 5.29
# Epoch 44:	########################################	elapsed: 0.20s, reconstruction error: 5.15
# Epoch 45:	########################################	elapsed: 0.19s, reconstruction error: 5.19
# Epoch 46:	########################################	elapsed: 0.20s, reconstruction error: 5.15
# Epoch 47:	########################################	elapsed: 0.18s, reconstruction error: 5.13
# Epoch 48:	########################################	elapsed: 0.22s, reconstruction error: 5.18
# Epoch 49:	########################################	elapsed: 0.18s, reconstruction error: 5.12
# Epoch 50:	########################################	elapsed: 0.19s, reconstruction error: 5.20
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.13s, reconstruction error: 14.26
# Epoch 2:	########################################	elapsed: 0.14s, reconstruction error: 10.49
# Epoch 3:	########################################	elapsed: 0.14s, reconstruction error: 8.89
# Epoch 4:	########################################	elapsed: 0.15s, reconstruction error: 8.10
# Epoch 5:	########################################	elapsed: 0.13s, reconstruction error: 7.45
# Epoch 6:	########################################	elapsed: 0.14s, reconstruction error: 6.12
# Epoch 7:	########################################	elapsed: 0.14s, reconstruction error: 5.52
# Epoch 8:	########################################	elapsed: 0.14s, reconstruction error: 5.18
# Epoch 9:	########################################	elapsed: 0.14s, reconstruction error: 5.01
# Epoch 10:	########################################	elapsed: 0.13s, reconstruction error: 4.81
# Epoch 11:	########################################	elapsed: 0.15s, reconstruction error: 4.72
# Epoch 12:	########################################	elapsed: 0.15s, reconstruction error: 4.55
# Epoch 13:	########################################	elapsed: 0.14s, reconstruction error: 4.52
# Epoch 14:	########################################	elapsed: 0.13s, reconstruction error: 4.46
# Epoch 15:	########################################	elapsed: 0.14s, reconstruction error: 4.39
# Epoch 16:	########################################	elapsed: 0.14s, reconstruction error: 4.36
# Epoch 17:	########################################	elapsed: 0.13s, reconstruction error: 4.19
# Epoch 18:	########################################	elapsed: 0.14s, reconstruction error: 4.22
# Epoch 19:	########################################	elapsed: 0.13s, reconstruction error: 4.20
# Epoch 20:	########################################	elapsed: 0.14s, reconstruction error: 4.21
# Epoch 21:	########################################	elapsed: 0.14s, reconstruction error: 4.18
# Epoch 22:	########################################	elapsed: 0.14s, reconstruction error: 4.14
# Epoch 23:	########################################	elapsed: 0.14s, reconstruction error: 4.16
# Epoch 24:	########################################	elapsed: 0.14s, reconstruction error: 4.19
# Epoch 25:	########################################	elapsed: 0.14s, reconstruction error: 4.10
# Epoch 26:	########################################	elapsed: 0.14s, reconstruction error: 4.09
# Epoch 27:	########################################	elapsed: 0.14s, reconstruction error: 4.11
# Epoch 28:	########################################	elapsed: 0.14s, reconstruction error: 4.17
# Epoch 29:	########################################	elapsed: 0.13s, reconstruction error: 4.03
# Epoch 30:	########################################	elapsed: 0.13s, reconstruction error: 4.03
# Epoch 31:	########################################	elapsed: 0.15s, reconstruction error: 4.02
# Epoch 32:	########################################	elapsed: 0.14s, reconstruction error: 4.06
# Epoch 33:	########################################	elapsed: 0.13s, reconstruction error: 4.00
# Epoch 34:	########################################	elapsed: 0.15s, reconstruction error: 4.02
# Epoch 35:	########################################	elapsed: 0.13s, reconstruction error: 3.94
# Epoch 36:	########################################	elapsed: 0.14s, reconstruction error: 3.97
# Epoch 37:	########################################	elapsed: 0.14s, reconstruction error: 4.00
# Epoch 38:	########################################	elapsed: 0.14s, reconstruction error: 3.90
# Epoch 39:	########################################	elapsed: 0.16s, reconstruction error: 4.05
# Epoch 40:	########################################	elapsed: 0.14s, reconstruction error: 3.98
# Epoch 41:	########################################	elapsed: 0.14s, reconstruction error: 4.00
# Epoch 42:	########################################	elapsed: 0.14s, reconstruction error: 4.03
# Epoch 43:	########################################	elapsed: 0.14s, reconstruction error: 3.95
# Epoch 44:	########################################	elapsed: 0.14s, reconstruction error: 3.96
# Epoch 45:	########################################	elapsed: 0.13s, reconstruction error: 3.98
# Epoch 46:	########################################	elapsed: 0.14s, reconstruction error: 3.94
# Epoch 47:	########################################	elapsed: 0.15s, reconstruction error: 3.90
# Epoch 48:	########################################	elapsed: 0.14s, reconstruction error: 3.91
# Epoch 49:	########################################	elapsed: 0.14s, reconstruction error: 3.90
# Epoch 50:	########################################	elapsed: 0.14s, reconstruction error: 3.92
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.09s, reconstruction error: 11.38
# Epoch 2:	########################################	elapsed: 0.10s, reconstruction error: 10.23
# Epoch 3:	########################################	elapsed: 0.09s, reconstruction error: 9.38
# Epoch 4:	########################################	elapsed: 0.10s, reconstruction error: 8.85
# Epoch 5:	########################################	elapsed: 0.09s, reconstruction error: 8.69
# Epoch 6:	########################################	elapsed: 0.10s, reconstruction error: 8.53
# Epoch 7:	########################################	elapsed: 0.09s, reconstruction error: 8.69
# Epoch 8:	########################################	elapsed: 0.10s, reconstruction error: 8.76
# Epoch 9:	########################################	elapsed: 0.09s, reconstruction error: 8.87
# Epoch 10:	########################################	elapsed: 0.10s, reconstruction error: 8.94
# Epoch 11:	########################################	elapsed: 0.10s, reconstruction error: 9.00
# Epoch 12:	########################################	elapsed: 0.10s, reconstruction error: 9.11
# Epoch 13:	########################################	elapsed: 0.09s, reconstruction error: 9.14
# Epoch 14:	########################################	elapsed: 0.10s, reconstruction error: 9.17
# Epoch 15:	########################################	elapsed: 0.09s, reconstruction error: 9.21
# Epoch 16:	########################################	elapsed: 0.10s, reconstruction error: 9.25
# Epoch 17:	########################################	elapsed: 0.10s, reconstruction error: 9.22
# Epoch 18:	########################################	elapsed: 0.10s, reconstruction error: 9.28
# Epoch 19:	########################################	elapsed: 0.09s, reconstruction error: 9.36
# Epoch 20:	########################################	elapsed: 0.10s, reconstruction error: 9.32
# Epoch 21:	########################################	elapsed: 0.09s, reconstruction error: 9.32
# Epoch 22:	########################################	elapsed: 0.10s, reconstruction error: 9.36
# Epoch 23:	########################################	elapsed: 0.10s, reconstruction error: 9.38
# Epoch 24:	########################################	elapsed: 0.09s, reconstruction error: 9.41
# Epoch 25:	########################################	elapsed: 0.09s, reconstruction error: 9.43
# Epoch 26:	########################################	elapsed: 0.10s, reconstruction error: 9.42
# Epoch 27:	########################################	elapsed: 0.10s, reconstruction error: 9.43
# Epoch 28:	########################################	elapsed: 0.10s, reconstruction error: 9.46
# Epoch 29:	########################################	elapsed: 0.09s, reconstruction error: 9.48
# Epoch 30:	########################################	elapsed: 0.10s, reconstruction error: 9.51
# Epoch 31:	########################################	elapsed: 0.09s, reconstruction error: 9.51
# Epoch 32:	########################################	elapsed: 0.10s, reconstruction error: 9.53
# Epoch 33:	########################################	elapsed: 0.10s, reconstruction error: 9.54
# Epoch 34:	########################################	elapsed: 0.10s, reconstruction error: 9.57
# Epoch 35:	########################################	elapsed: 0.09s, reconstruction error: 9.59
# Epoch 36:	########################################	elapsed: 0.10s, reconstruction error: 9.62
# Epoch 37:	########################################	elapsed: 0.10s, reconstruction error: 9.62
# Epoch 38:	########################################	elapsed: 0.10s, reconstruction error: 9.61
# Epoch 39:	########################################	elapsed: 0.10s, reconstruction error: 9.65
# Epoch 40:	########################################	elapsed: 0.10s, reconstruction error: 9.65
# Epoch 41:	########################################	elapsed: 0.10s, reconstruction error: 9.64
# Epoch 42:	########################################	elapsed: 0.09s, reconstruction error: 9.70
# Epoch 43:	########################################	elapsed: 0.10s, reconstruction error: 9.69
# Epoch 44:	########################################	elapsed: 0.10s, reconstruction error: 9.70
# Epoch 45:	########################################	elapsed: 0.10s, reconstruction error: 9.70
# Epoch 46:	########################################	elapsed: 0.09s, reconstruction error: 9.70
# Epoch 47:	########################################	elapsed: 0.10s, reconstruction error: 9.70
# Epoch 48:	########################################	elapsed: 0.09s, reconstruction error: 9.71
# Epoch 49:	########################################	elapsed: 0.10s, reconstruction error: 9.73
# Epoch 50:	########################################	elapsed: 0.09s, reconstruction error: 9.73
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 137.26
#
# Epoch 1:	########################################	elapsed: 0.70s, cross-entropy: 106.91
# Epoch 2:	########################################	elapsed: 0.71s, cross-entropy: 103.66
# Epoch 3:	########################################	elapsed: 0.72s, cross-entropy: 101.88
# Epoch 4:	########################################	elapsed: 0.68s, cross-entropy: 100.54
# Epoch 5:	########################################	elapsed: 0.69s, cross-entropy: 99.51
# Epoch 6:	########################################	elapsed: 0.75s, cross-entropy: 98.69
# Epoch 7:	########################################	elapsed: 0.72s, cross-entropy: 97.97
# Epoch 8:	########################################	elapsed: 0.72s, cross-entropy: 97.26
# Epoch 9:	########################################	elapsed: 0.77s, cross-entropy: 96.62
# Epoch 10:	########################################	elapsed: 0.83s, cross-entropy: 96.21
# Epoch 11:	########################################	elapsed: 0.76s, cross-entropy: 95.80
# Epoch 12:	########################################	elapsed: 0.73s, cross-entropy: 95.38
# Epoch 13:	########################################	elapsed: 0.75s, cross-entropy: 95.09
# Epoch 14:	########################################	elapsed: 0.75s, cross-entropy: 94.91
# Epoch 15:	########################################	elapsed: 0.72s, cross-entropy: 94.67
# Epoch 16:	########################################	elapsed: 0.84s, cross-entropy: 94.41
# Epoch 17:	########################################	elapsed: 0.73s, cross-entropy: 94.09
# Epoch 18:	########################################	elapsed: 0.72s, cross-entropy: 93.85
# Epoch 19:	########################################	elapsed: 0.74s, cross-entropy: 93.66
# Epoch 20:	########################################	elapsed: 0.72s, cross-entropy: 93.73
# Epoch 21:	########################################	elapsed: 0.69s, cross-entropy: 93.84
# Epoch 22:	########################################	elapsed: 0.73s, cross-entropy: 93.84
# Epoch 23:	########################################	elapsed: 0.68s, cross-entropy: 93.27
# Epoch 24:	########################################	elapsed: 0.71s, cross-entropy: 93.15
# Epoch 25:	########################################	elapsed: 0.67s, cross-entropy: 93.10
# Epoch 26:	########################################	elapsed: 0.73s, cross-entropy: 92.97
# Epoch 27:	########################################	elapsed: 0.72s, cross-entropy: 93.13
# Epoch 28:	########################################	elapsed: 0.71s, cross-entropy: 93.62
# Epoch 29:	########################################	elapsed: 0.70s, cross-entropy: 93.48
# Epoch 30:	########################################	elapsed: 0.71s, cross-entropy: 93.04
# Epoch 31:	########################################	elapsed: 0.72s, cross-entropy: 92.32
# Epoch 32:	########################################	elapsed: 0.73s, cross-entropy: 92.18
# Epoch 33:	########################################	elapsed: 0.69s, cross-entropy: 92.32
# Epoch 34:	########################################	elapsed: 0.69s, cross-entropy: 92.16
# Epoch 35:	########################################	elapsed: 0.68s, cross-entropy: 92.58
# Epoch 36:	########################################	elapsed: 0.69s, cross-entropy: 92.71
# Epoch 37:	########################################	elapsed: 0.69s, cross-entropy: 92.91
# Epoch 38:	########################################	elapsed: 0.70s, cross-entropy: 93.03
# Epoch 39:	########################################	elapsed: 0.80s, cross-entropy: 93.80
# Epoch 40:	########################################	elapsed: 0.68s, cross-entropy: 92.92
# Epoch 41:	########################################	elapsed: 0.69s, cross-entropy: 91.88
# Epoch 42:	########################################	elapsed: 0.72s, cross-entropy: 91.77
# Epoch 43:	########################################	elapsed: 0.72s, cross-entropy: 91.42
# Epoch 44:	########################################	elapsed: 0.68s, cross-entropy: 91.25
# Epoch 45:	########################################	elapsed: 0.70s, cross-entropy: 90.86
# Epoch 46:	########################################	elapsed: 0.72s, cross-entropy: 90.43
# Epoch 47:	########################################	elapsed: 0.67s, cross-entropy: 89.91
# Epoch 48:	########################################	elapsed: 0.74s, cross-entropy: 89.76
# Epoch 49:	########################################	elapsed: 0.69s, cross-entropy: 89.66
# Epoch 50:	########################################	elapsed: 0.72s, cross-entropy: 89.89
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned AE</h3>
# <h3>Input minibatch</h3>
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>
