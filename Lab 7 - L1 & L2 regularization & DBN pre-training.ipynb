# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch):
    return 1.0 / (1.0 + np.exp(-batch))

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Part 1: $L^1$ and $L^2$ penalties

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum, l1_penalty, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l1_penalty = l1_penalty
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:,:-1]) > rand(hidden.shape[0], hidden.shape[1] -1)
    visible = sigmoid(hidden @ rbm.W[:-1,:].T)
    error = np.sum((minibatch[:, :-1] - visible)**2) / observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### CDK with regulatization
#
# Implement the Contrastive Divergence algorithm with $L^1$ and $L^2$ penalties. If
# ```python
# rbm.l1_penalty > 0
# ```
# the algorithm should constrain the weights with $L^1$ penalty. Otherwise, if
# ```python
# rbm.l2_penalty > 0
# ```
# the algorithm should constrain the weights with $L^2$ penalty.
#
# Do **not** apply the penalties to the biases!

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    # activation matrices during positive and negative phases in visible (v) layer, with bias
    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    # activation matrices during positive and negative phases in hidden (h) layer, with biases
    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # POSITIVE PHASE
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    pos_grad = (positive_visible.T @ positive_hidden) / observations_count

    # NEGATIVE PHASE
    # Gibbs sampling
    # remove last column (hidden layer) or last row (visible layer) from the weight matrix W, 
    # since those are biases and should always be 1
    pos_h_rand_shape = positive_hidden.shape[0], positive_hidden.shape[1] - 1
    neg_h_rand_shape = negative_hidden.shape[0], negative_hidden.shape[1] - 1
    neg_v_rand_shape = negative_visible.shape[0], negative_visible.shape[1] - 1
    
    # sample hidden layer, get h_0
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(*pos_h_rand_shape)
    
    # sample visible layer, get v_1
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*neg_v_rand_shape)
    
    for _ in range(k - 1):
        # sample hidden layer, get h_{k-1}
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(*neg_h_rand_shape)
        
        # sample visible layer, get v_k
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*neg_v_rand_shape)
    
    # h_k, to match v_k
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    neg_grad = (negative_visible.T @ negative_hidden) / observations_count
    
    # WEIGHT UPDATE WITH REGULARIZATION AND MOMENTUM
    gradient = pos_grad - neg_grad
    
    # REGULARIZATION
    if rbm.l1_penalty > 0:
        gradient[:-1, :-1] -= rbm.l1_penalty * np.sign(rbm.W[:-1, :-1])
    
    if rbm.l2_penalty > 0:
        gradient[:-1, :-1] -= rbm.l2_penalty * rbm.W[:-1, :-1]
    
    rbm.M = rbm.momentum * rbm.M + rbm.learning_rate * gradient
    rbm.W += rbm.M

# %% [markdown]
# ## Comparison of regularization penalties

# %%
DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

# %% [markdown]
# ### RBM with no regularization

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_plain = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_plain, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.46s, reconstruction error: 25.99
# Epoch 2:	########################################	elapsed: 0.41s, reconstruction error: 20.88
# Epoch 3:	########################################	elapsed: 0.40s, reconstruction error: 18.56
# Epoch 4:	########################################	elapsed: 0.40s, reconstruction error: 17.11
# Epoch 5:	########################################	elapsed: 0.41s, reconstruction error: 16.16
# Epoch 6:	########################################	elapsed: 0.41s, reconstruction error: 15.08
# Epoch 7:	########################################	elapsed: 0.44s, reconstruction error: 14.23
# Epoch 8:	########################################	elapsed: 0.44s, reconstruction error: 13.54
# Epoch 9:	########################################	elapsed: 0.48s, reconstruction error: 12.89
# Epoch 10:	########################################	elapsed: 0.47s, reconstruction error: 12.52
# Epoch 11:	########################################	elapsed: 0.48s, reconstruction error: 12.10
# Epoch 12:	########################################	elapsed: 0.48s, reconstruction error: 11.86
# Epoch 13:	########################################	elapsed: 0.50s, reconstruction error: 11.70
# Epoch 14:	########################################	elapsed: 0.50s, reconstruction error: 11.40
# Epoch 15:	########################################	elapsed: 0.50s, reconstruction error: 11.36
# Epoch 16:	########################################	elapsed: 0.48s, reconstruction error: 11.27
# Epoch 17:	########################################	elapsed: 0.51s, reconstruction error: 11.12
# Epoch 18:	########################################	elapsed: 0.51s, reconstruction error: 10.99
# Epoch 19:	########################################	elapsed: 0.50s, reconstruction error: 10.96
# Epoch 20:	########################################	elapsed: 0.50s, reconstruction error: 10.75
# Epoch 21:	########################################	elapsed: 0.50s, reconstruction error: 10.67
# Epoch 22:	########################################	elapsed: 0.45s, reconstruction error: 10.44
# Epoch 23:	########################################	elapsed: 0.47s, reconstruction error: 10.54
# Epoch 24:	########################################	elapsed: 0.48s, reconstruction error: 10.53
# Epoch 25:	########################################	elapsed: 0.46s, reconstruction error: 10.53
# Epoch 26:	########################################	elapsed: 0.45s, reconstruction error: 10.57
# Epoch 27:	########################################	elapsed: 0.43s, reconstruction error: 10.42
# Epoch 28:	########################################	elapsed: 0.43s, reconstruction error: 10.40
# Epoch 29:	########################################	elapsed: 0.43s, reconstruction error: 10.15
# Epoch 30:	########################################	elapsed: 0.45s, reconstruction error: 10.20
# Epoch 31:	########################################	elapsed: 0.50s, reconstruction error: 10.35
# Epoch 32:	########################################	elapsed: 0.49s, reconstruction error: 10.16
# Epoch 33:	########################################	elapsed: 0.43s, reconstruction error: 10.30
# Epoch 34:	########################################	elapsed: 0.43s, reconstruction error: 10.03
# Epoch 35:	########################################	elapsed: 0.48s, reconstruction error: 10.16
# Epoch 36:	########################################	elapsed: 0.42s, reconstruction error: 10.08
# Epoch 37:	########################################	elapsed: 0.44s, reconstruction error: 10.05
# Epoch 38:	########################################	elapsed: 0.42s, reconstruction error: 9.98
# Epoch 39:	########################################	elapsed: 0.43s, reconstruction error: 10.12
# Epoch 40:	########################################	elapsed: 0.46s, reconstruction error: 10.11
# Epoch 41:	########################################	elapsed: 0.42s, reconstruction error: 10.07
# Epoch 42:	########################################	elapsed: 0.45s, reconstruction error: 10.05
# Epoch 43:	########################################	elapsed: 0.46s, reconstruction error: 10.12
# Epoch 44:	########################################	elapsed: 0.45s, reconstruction error: 10.09
# Epoch 45:	########################################	elapsed: 0.47s, reconstruction error: 9.96
# Epoch 46:	########################################	elapsed: 0.52s, reconstruction error: 10.02
# Epoch 47:	########################################	elapsed: 0.44s, reconstruction error: 10.11
# Epoch 48:	########################################	elapsed: 0.50s, reconstruction error: 9.89
# Epoch 49:	########################################	elapsed: 0.50s, reconstruction error: 9.87
# Epoch 50:	########################################	elapsed: 0.50s, reconstruction error: 10.00
# Training finished!

# %% [markdown]
# ### RBM with $L^1$ penalty

# %%
L1_PENALTY = 0.0001
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_l1 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l1, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.54s, reconstruction error: 26.10
# Epoch 2:	########################################	elapsed: 0.54s, reconstruction error: 20.91
# Epoch 3:	########################################	elapsed: 0.53s, reconstruction error: 18.63
# Epoch 4:	########################################	elapsed: 0.54s, reconstruction error: 17.15
# Epoch 5:	########################################	elapsed: 0.55s, reconstruction error: 16.14
# Epoch 6:	########################################	elapsed: 0.47s, reconstruction error: 15.12
# Epoch 7:	########################################	elapsed: 0.53s, reconstruction error: 14.14
# Epoch 8:	########################################	elapsed: 0.57s, reconstruction error: 13.44
# Epoch 9:	########################################	elapsed: 0.53s, reconstruction error: 12.78
# Epoch 10:	########################################	elapsed: 0.50s, reconstruction error: 12.24
# Epoch 11:	########################################	elapsed: 0.49s, reconstruction error: 11.93
# Epoch 12:	########################################	elapsed: 0.51s, reconstruction error: 11.77
# Epoch 13:	########################################	elapsed: 0.57s, reconstruction error: 11.50
# Epoch 14:	########################################	elapsed: 0.55s, reconstruction error: 11.13
# Epoch 15:	########################################	elapsed: 0.54s, reconstruction error: 11.25
# Epoch 16:	########################################	elapsed: 0.50s, reconstruction error: 11.01
# Epoch 17:	########################################	elapsed: 0.53s, reconstruction error: 11.02
# Epoch 18:	########################################	elapsed: 0.54s, reconstruction error: 10.77
# Epoch 19:	########################################	elapsed: 0.57s, reconstruction error: 10.88
# Epoch 20:	########################################	elapsed: 0.52s, reconstruction error: 10.64
# Epoch 21:	########################################	elapsed: 0.54s, reconstruction error: 10.53
# Epoch 22:	########################################	elapsed: 0.51s, reconstruction error: 10.45
# Epoch 23:	########################################	elapsed: 0.51s, reconstruction error: 10.56
# Epoch 24:	########################################	elapsed: 0.49s, reconstruction error: 10.44
# Epoch 25:	########################################	elapsed: 0.51s, reconstruction error: 10.30
# Epoch 26:	########################################	elapsed: 0.49s, reconstruction error: 10.36
# Epoch 27:	########################################	elapsed: 0.52s, reconstruction error: 10.20
# Epoch 28:	########################################	elapsed: 0.51s, reconstruction error: 10.21
# Epoch 29:	########################################	elapsed: 0.49s, reconstruction error: 10.08
# Epoch 30:	########################################	elapsed: 0.57s, reconstruction error: 10.24
# Epoch 31:	########################################	elapsed: 0.51s, reconstruction error: 10.23
# Epoch 32:	########################################	elapsed: 0.54s, reconstruction error: 10.10
# Epoch 33:	########################################	elapsed: 0.60s, reconstruction error: 10.10
# Epoch 34:	########################################	elapsed: 0.56s, reconstruction error: 10.02
# Epoch 35:	########################################	elapsed: 0.49s, reconstruction error: 10.01
# Epoch 36:	########################################	elapsed: 0.49s, reconstruction error: 10.02
# Epoch 37:	########################################	elapsed: 0.48s, reconstruction error: 10.08
# Epoch 38:	########################################	elapsed: 0.49s, reconstruction error: 9.88
# Epoch 39:	########################################	elapsed: 0.49s, reconstruction error: 9.69
# Epoch 40:	########################################	elapsed: 0.49s, reconstruction error: 9.86
# Epoch 41:	########################################	elapsed: 0.52s, reconstruction error: 10.01
# Epoch 42:	########################################	elapsed: 0.52s, reconstruction error: 10.00
# Epoch 43:	########################################	elapsed: 0.51s, reconstruction error: 10.00
# Epoch 44:	########################################	elapsed: 0.53s, reconstruction error: 9.95
# Epoch 45:	########################################	elapsed: 0.54s, reconstruction error: 10.04
# Epoch 46:	########################################	elapsed: 0.55s, reconstruction error: 9.89
# Epoch 47:	########################################	elapsed: 0.56s, reconstruction error: 9.85
# Epoch 48:	########################################	elapsed: 0.56s, reconstruction error: 9.86
# Epoch 49:	########################################	elapsed: 0.56s, reconstruction error: 9.79
# Epoch 50:	########################################	elapsed: 0.56s, reconstruction error: 9.93
# Training finished!

# %% [markdown]
# ### RBM with $L^2$ penalty

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0005

np.random.seed(1234)
rbm_l2 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l2, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.44s, reconstruction error: 26.09
# Epoch 2:	########################################	elapsed: 0.48s, reconstruction error: 20.92
# Epoch 3:	########################################	elapsed: 0.46s, reconstruction error: 18.66
# Epoch 4:	########################################	elapsed: 0.44s, reconstruction error: 17.25
# Epoch 5:	########################################	elapsed: 0.44s, reconstruction error: 16.25
# Epoch 6:	########################################	elapsed: 0.47s, reconstruction error: 15.23
# Epoch 7:	########################################	elapsed: 0.47s, reconstruction error: 14.24
# Epoch 8:	########################################	elapsed: 0.45s, reconstruction error: 13.62
# Epoch 9:	########################################	elapsed: 0.42s, reconstruction error: 13.00
# Epoch 10:	########################################	elapsed: 0.51s, reconstruction error: 12.57
# Epoch 11:	########################################	elapsed: 0.46s, reconstruction error: 12.14
# Epoch 12:	########################################	elapsed: 0.44s, reconstruction error: 12.14
# Epoch 13:	########################################	elapsed: 0.51s, reconstruction error: 11.97
# Epoch 14:	########################################	elapsed: 0.47s, reconstruction error: 11.61
# Epoch 15:	########################################	elapsed: 0.45s, reconstruction error: 11.54
# Epoch 16:	########################################	elapsed: 0.48s, reconstruction error: 11.45
# Epoch 17:	########################################	elapsed: 0.45s, reconstruction error: 11.27
# Epoch 18:	########################################	elapsed: 0.50s, reconstruction error: 11.10
# Epoch 19:	########################################	elapsed: 0.51s, reconstruction error: 11.03
# Epoch 20:	########################################	elapsed: 0.49s, reconstruction error: 10.93
# Epoch 21:	########################################	elapsed: 0.47s, reconstruction error: 10.83
# Epoch 22:	########################################	elapsed: 0.47s, reconstruction error: 10.69
# Epoch 23:	########################################	elapsed: 0.42s, reconstruction error: 10.74
# Epoch 24:	########################################	elapsed: 0.48s, reconstruction error: 10.75
# Epoch 25:	########################################	elapsed: 0.47s, reconstruction error: 10.68
# Epoch 26:	########################################	elapsed: 0.46s, reconstruction error: 10.58
# Epoch 27:	########################################	elapsed: 0.47s, reconstruction error: 10.38
# Epoch 28:	########################################	elapsed: 0.39s, reconstruction error: 10.58
# Epoch 29:	########################################	elapsed: 0.46s, reconstruction error: 10.26
# Epoch 30:	########################################	elapsed: 0.54s, reconstruction error: 10.39
# Epoch 31:	########################################	elapsed: 0.49s, reconstruction error: 10.51
# Epoch 32:	########################################	elapsed: 0.47s, reconstruction error: 10.38
# Epoch 33:	########################################	elapsed: 0.48s, reconstruction error: 10.42
# Epoch 34:	########################################	elapsed: 0.44s, reconstruction error: 10.24
# Epoch 35:	########################################	elapsed: 0.52s, reconstruction error: 10.35
# Epoch 36:	########################################	elapsed: 0.48s, reconstruction error: 10.31
# Epoch 37:	########################################	elapsed: 0.47s, reconstruction error: 10.34
# Epoch 38:	########################################	elapsed: 0.43s, reconstruction error: 10.21
# Epoch 39:	########################################	elapsed: 0.47s, reconstruction error: 10.13
# Epoch 40:	########################################	elapsed: 0.46s, reconstruction error: 10.22
# Epoch 41:	########################################	elapsed: 0.46s, reconstruction error: 10.00
# Epoch 42:	########################################	elapsed: 0.47s, reconstruction error: 10.10
# Epoch 43:	########################################	elapsed: 0.46s, reconstruction error: 10.26
# Epoch 44:	########################################	elapsed: 0.47s, reconstruction error: 10.24
# Epoch 45:	########################################	elapsed: 0.48s, reconstruction error: 10.16
# Epoch 46:	########################################	elapsed: 0.43s, reconstruction error: 10.07
# Epoch 47:	########################################	elapsed: 0.47s, reconstruction error: 10.25
# Epoch 48:	########################################	elapsed: 0.48s, reconstruction error: 10.14
# Epoch 49:	########################################	elapsed: 0.44s, reconstruction error: 10.16
# Epoch 50:	########################################	elapsed: 0.46s, reconstruction error: 10.05
# Training finished!

# %% [markdown]
# ### Plain filters

# %%
draw_filters(rbm_plain)

# %% [markdown]
# ### $L^1$ filters

# %%
draw_filters(rbm_l1)

# %% [markdown]
# ### $L^2$ filters

# %%
draw_filters(rbm_l2)

# %% [markdown]
# # Part 2: MLP pretraining

# %%
def softmax(batch):
    normalized_batch = batch - np.max(batch, axis=1, keepdims=True)
    exp_normalized_batch = np.exp(normalized_batch)
    return exp_normalized_batch / np.sum(exp_normalized_batch, axis=1, keepdims=True)

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation
#
# Extend the implementation of error backpropagation (from Lab 6) with $L^2$ penalty. Apply the penalty when:
# ```python
# rbm.l2_penalty > 0
# ```
#
# Do **not** apply the penalty to the biases.

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]            
            visible = prev_layer.activations
            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count
        if layer.l2_penalty > 0:
            gradient += layer.l2_penalty * layer.W
        
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        layer.W += layer.M

# %% [markdown]
# ### MLP training

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
    
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def run_mlp_training(mlp, train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count):
    
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = 0.9
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")
    
def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ## DBN Pretraining

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    dbn_propagated = propagate_up(dbn, layers_count, minibatch)
    
    return reconstuction_error(dbn[layers_count], dbn_propagated)

# %%
def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# ##  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for layer_idx, layer in enumerate(dbn):
        mlp[layer_idx].W = np.copy(layer.W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
np.random.seed(1234)

DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %% [markdown]
# ### Plain vs pretrained MLP comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5
L2_PENALTY = 0.00002

# %% [markdown]
# ### Shallow neural network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

shallow_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in shallow_mlp[:-1]
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.26s, accuracy: 10.10
# Epoch 2:	########################################	elapsed: 0.23s, accuracy: 10.10
# Epoch 3:	########################################	elapsed: 0.22s, accuracy: 8.92
# Epoch 4:	########################################	elapsed: 0.23s, accuracy: 8.92
# Epoch 5:	########################################	elapsed: 0.22s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.23s, accuracy: 15.02
# Epoch 7:	########################################	elapsed: 0.23s, accuracy: 27.15
# Epoch 8:	########################################	elapsed: 0.24s, accuracy: 31.93
# Epoch 9:	########################################	elapsed: 0.23s, accuracy: 33.29
# Epoch 10:	########################################	elapsed: 0.22s, accuracy: 46.86
# Epoch 11:	########################################	elapsed: 0.24s, accuracy: 52.82
# Epoch 12:	########################################	elapsed: 0.23s, accuracy: 58.69
# Epoch 13:	########################################	elapsed: 0.22s, accuracy: 69.29
# Epoch 14:	########################################	elapsed: 0.22s, accuracy: 80.92
# Epoch 15:	########################################	elapsed: 0.23s, accuracy: 84.71
# Epoch 16:	########################################	elapsed: 0.21s, accuracy: 86.90
# Epoch 17:	########################################	elapsed: 0.21s, accuracy: 88.13
# Epoch 18:	########################################	elapsed: 0.22s, accuracy: 89.19
# Epoch 19:	########################################	elapsed: 0.21s, accuracy: 90.03
# Epoch 20:	########################################	elapsed: 0.23s, accuracy: 90.75
# Epoch 21:	########################################	elapsed: 0.22s, accuracy: 91.08
# Epoch 22:	########################################	elapsed: 0.21s, accuracy: 91.51
# Epoch 23:	########################################	elapsed: 0.22s, accuracy: 91.63
# Epoch 24:	########################################	elapsed: 0.22s, accuracy: 91.91
# Epoch 25:	########################################	elapsed: 0.22s, accuracy: 92.00
# Epoch 26:	########################################	elapsed: 0.22s, accuracy: 92.26
# Epoch 27:	########################################	elapsed: 0.22s, accuracy: 92.56
# Epoch 28:	########################################	elapsed: 0.22s, accuracy: 92.74
# Epoch 29:	########################################	elapsed: 0.23s, accuracy: 92.96
# Epoch 30:	########################################	elapsed: 0.24s, accuracy: 93.19
# Epoch 31:	########################################	elapsed: 0.23s, accuracy: 93.09
# Epoch 32:	########################################	elapsed: 0.22s, accuracy: 93.03
# Epoch 33:	########################################	elapsed: 0.24s, accuracy: 93.17
# Epoch 34:	########################################	elapsed: 0.22s, accuracy: 93.60
# Epoch 35:	########################################	elapsed: 0.22s, accuracy: 93.79
# Epoch 36:	########################################	elapsed: 0.22s, accuracy: 93.94
# Epoch 37:	########################################	elapsed: 0.25s, accuracy: 93.88
# Epoch 38:	########################################	elapsed: 0.22s, accuracy: 93.90
# Epoch 39:	########################################	elapsed: 0.24s, accuracy: 93.89
# Epoch 40:	########################################	elapsed: 0.23s, accuracy: 93.78
# Epoch 41:	########################################	elapsed: 0.23s, accuracy: 93.70
# Epoch 42:	########################################	elapsed: 0.23s, accuracy: 93.58
# Epoch 43:	########################################	elapsed: 0.23s, accuracy: 93.53
# Epoch 44:	########################################	elapsed: 0.24s, accuracy: 93.51
# Epoch 45:	########################################	elapsed: 0.22s, accuracy: 93.56
# Epoch 46:	########################################	elapsed: 0.23s, accuracy: 93.55
# Epoch 47:	########################################	elapsed: 0.23s, accuracy: 93.53
# Epoch 48:	########################################	elapsed: 0.23s, accuracy: 93.64
# Epoch 49:	########################################	elapsed: 0.22s, accuracy: 93.77
# Epoch 50:	########################################	elapsed: 0.22s, accuracy: 93.91
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.38s, reconstruction error: 31.78
# Epoch 2:	########################################	elapsed: 0.36s, reconstruction error: 24.92
# Epoch 3:	########################################	elapsed: 0.37s, reconstruction error: 21.41
# Epoch 4:	########################################	elapsed: 0.36s, reconstruction error: 18.99
# Epoch 5:	########################################	elapsed: 0.36s, reconstruction error: 17.71
# Epoch 6:	########################################	elapsed: 0.35s, reconstruction error: 15.32
# Epoch 7:	########################################	elapsed: 0.36s, reconstruction error: 13.39
# Epoch 8:	########################################	elapsed: 0.36s, reconstruction error: 12.39
# Epoch 9:	########################################	elapsed: 0.39s, reconstruction error: 11.86
# Epoch 10:	########################################	elapsed: 0.36s, reconstruction error: 11.44
# Epoch 11:	########################################	elapsed: 0.36s, reconstruction error: 11.04
# Epoch 12:	########################################	elapsed: 0.35s, reconstruction error: 10.76
# Epoch 13:	########################################	elapsed: 0.36s, reconstruction error: 10.50
# Epoch 14:	########################################	elapsed: 0.36s, reconstruction error: 10.43
# Epoch 15:	########################################	elapsed: 0.36s, reconstruction error: 10.23
# Epoch 16:	########################################	elapsed: 0.35s, reconstruction error: 9.89
# Epoch 17:	########################################	elapsed: 0.40s, reconstruction error: 9.94
# Epoch 18:	########################################	elapsed: 0.36s, reconstruction error: 9.70
# Epoch 19:	########################################	elapsed: 0.36s, reconstruction error: 9.43
# Epoch 20:	########################################	elapsed: 0.36s, reconstruction error: 9.66
# Epoch 21:	########################################	elapsed: 0.34s, reconstruction error: 9.57
# Epoch 22:	########################################	elapsed: 0.37s, reconstruction error: 9.38
# Epoch 23:	########################################	elapsed: 0.37s, reconstruction error: 9.48
# Epoch 24:	########################################	elapsed: 0.36s, reconstruction error: 9.38
# Epoch 25:	########################################	elapsed: 0.71s, reconstruction error: 9.42
# Epoch 26:	########################################	elapsed: 0.37s, reconstruction error: 9.30
# Epoch 27:	########################################	elapsed: 0.38s, reconstruction error: 9.24
# Epoch 28:	########################################	elapsed: 0.34s, reconstruction error: 9.26
# Epoch 29:	########################################	elapsed: 0.35s, reconstruction error: 9.12
# Epoch 30:	########################################	elapsed: 0.36s, reconstruction error: 9.06
# Epoch 31:	########################################	elapsed: 0.36s, reconstruction error: 9.07
# Epoch 32:	########################################	elapsed: 0.35s, reconstruction error: 8.95
# Epoch 33:	########################################	elapsed: 0.36s, reconstruction error: 9.00
# Epoch 34:	########################################	elapsed: 0.36s, reconstruction error: 8.90
# Epoch 35:	########################################	elapsed: 0.37s, reconstruction error: 8.94
# Epoch 36:	########################################	elapsed: 0.36s, reconstruction error: 8.81
# Epoch 37:	########################################	elapsed: 0.36s, reconstruction error: 8.82
# Epoch 38:	########################################	elapsed: 0.36s, reconstruction error: 8.88
# Epoch 39:	########################################	elapsed: 0.35s, reconstruction error: 8.90
# Epoch 40:	########################################	elapsed: 0.35s, reconstruction error: 8.91
# Epoch 41:	########################################	elapsed: 0.37s, reconstruction error: 8.72
# Epoch 42:	########################################	elapsed: 0.35s, reconstruction error: 8.79
# Epoch 43:	########################################	elapsed: 0.36s, reconstruction error: 8.74
# Epoch 44:	########################################	elapsed: 0.36s, reconstruction error: 8.65
# Epoch 45:	########################################	elapsed: 0.36s, reconstruction error: 8.75
# Epoch 46:	########################################	elapsed: 0.37s, reconstruction error: 8.62
# Epoch 47:	########################################	elapsed: 0.35s, reconstruction error: 8.78
# Epoch 48:	########################################	elapsed: 0.36s, reconstruction error: 8.61
# Epoch 49:	########################################	elapsed: 0.36s, reconstruction error: 8.65
# Epoch 50:	########################################	elapsed: 0.36s, reconstruction error: 8.58
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.21s, reconstruction error: 19.47
# Epoch 2:	########################################	elapsed: 0.22s, reconstruction error: 14.85
# Epoch 3:	########################################	elapsed: 0.21s, reconstruction error: 12.59
# Epoch 4:	########################################	elapsed: 0.21s, reconstruction error: 11.26
# Epoch 5:	########################################	elapsed: 0.20s, reconstruction error: 10.36
# Epoch 6:	########################################	elapsed: 0.21s, reconstruction error: 8.53
# Epoch 7:	########################################	elapsed: 0.19s, reconstruction error: 7.20
# Epoch 8:	########################################	elapsed: 0.20s, reconstruction error: 6.63
# Epoch 9:	########################################	elapsed: 0.21s, reconstruction error: 6.27
# Epoch 10:	########################################	elapsed: 0.21s, reconstruction error: 5.95
# Epoch 11:	########################################	elapsed: 0.21s, reconstruction error: 5.57
# Epoch 12:	########################################	elapsed: 0.21s, reconstruction error: 5.36
# Epoch 13:	########################################	elapsed: 0.21s, reconstruction error: 5.30
# Epoch 14:	########################################	elapsed: 0.21s, reconstruction error: 5.09
# Epoch 15:	########################################	elapsed: 0.20s, reconstruction error: 5.06
# Epoch 16:	########################################	elapsed: 0.19s, reconstruction error: 4.83
# Epoch 17:	########################################	elapsed: 0.20s, reconstruction error: 4.91
# Epoch 18:	########################################	elapsed: 0.19s, reconstruction error: 4.73
# Epoch 19:	########################################	elapsed: 0.21s, reconstruction error: 4.76
# Epoch 20:	########################################	elapsed: 0.21s, reconstruction error: 4.70
# Epoch 21:	########################################	elapsed: 0.21s, reconstruction error: 4.62
# Epoch 22:	########################################	elapsed: 0.22s, reconstruction error: 4.57
# Epoch 23:	########################################	elapsed: 0.21s, reconstruction error: 4.53
# Epoch 24:	########################################	elapsed: 0.19s, reconstruction error: 4.48
# Epoch 25:	########################################	elapsed: 0.20s, reconstruction error: 4.54
# Epoch 26:	########################################	elapsed: 0.20s, reconstruction error: 4.40
# Epoch 27:	########################################	elapsed: 0.22s, reconstruction error: 4.30
# Epoch 28:	########################################	elapsed: 0.22s, reconstruction error: 4.36
# Epoch 29:	########################################	elapsed: 0.20s, reconstruction error: 4.34
# Epoch 30:	########################################	elapsed: 0.21s, reconstruction error: 4.38
# Epoch 31:	########################################	elapsed: 0.21s, reconstruction error: 4.37
# Epoch 32:	########################################	elapsed: 0.20s, reconstruction error: 4.25
# Epoch 33:	########################################	elapsed: 0.21s, reconstruction error: 4.28
# Epoch 34:	########################################	elapsed: 0.21s, reconstruction error: 4.23
# Epoch 35:	########################################	elapsed: 0.21s, reconstruction error: 4.19
# Epoch 36:	########################################	elapsed: 0.20s, reconstruction error: 4.19
# Epoch 37:	########################################	elapsed: 0.21s, reconstruction error: 4.20
# Epoch 38:	########################################	elapsed: 0.21s, reconstruction error: 4.15
# Epoch 39:	########################################	elapsed: 0.21s, reconstruction error: 4.10
# Epoch 40:	########################################	elapsed: 0.22s, reconstruction error: 4.15
# Epoch 41:	########################################	elapsed: 0.21s, reconstruction error: 4.18
# Epoch 42:	########################################	elapsed: 0.22s, reconstruction error: 4.17
# Epoch 43:	########################################	elapsed: 0.21s, reconstruction error: 4.10
# Epoch 44:	########################################	elapsed: 0.20s, reconstruction error: 4.05
# Epoch 45:	########################################	elapsed: 0.21s, reconstruction error: 4.15
# Epoch 46:	########################################	elapsed: 0.22s, reconstruction error: 4.11
# Epoch 47:	########################################	elapsed: 0.20s, reconstruction error: 4.10
# Epoch 48:	########################################	elapsed: 0.21s, reconstruction error: 4.08
# Epoch 49:	########################################	elapsed: 0.20s, reconstruction error: 4.06
# Epoch 50:	########################################	elapsed: 0.22s, reconstruction error: 4.07
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.23s, accuracy: 93.71
# Epoch 2:	########################################	elapsed: 0.23s, accuracy: 94.94
# Epoch 3:	########################################	elapsed: 0.22s, accuracy: 95.54
# Epoch 4:	########################################	elapsed: 0.23s, accuracy: 95.85
# Epoch 5:	########################################	elapsed: 0.22s, accuracy: 96.07
# Epoch 6:	########################################	elapsed: 0.23s, accuracy: 96.20
# Epoch 7:	########################################	elapsed: 0.23s, accuracy: 96.31
# Epoch 8:	########################################	elapsed: 0.24s, accuracy: 96.47
# Epoch 9:	########################################	elapsed: 0.24s, accuracy: 96.52
# Epoch 10:	########################################	elapsed: 0.23s, accuracy: 96.54
# Epoch 11:	########################################	elapsed: 0.24s, accuracy: 96.54
# Epoch 12:	########################################	elapsed: 0.24s, accuracy: 96.57
# Epoch 13:	########################################	elapsed: 0.23s, accuracy: 96.63
# Epoch 14:	########################################	elapsed: 0.25s, accuracy: 96.66
# Epoch 15:	########################################	elapsed: 0.23s, accuracy: 96.65
# Epoch 16:	########################################	elapsed: 0.22s, accuracy: 96.66
# Epoch 17:	########################################	elapsed: 0.23s, accuracy: 96.65
# Epoch 18:	########################################	elapsed: 0.23s, accuracy: 96.64
# Epoch 19:	########################################	elapsed: 0.22s, accuracy: 96.64
# Epoch 20:	########################################	elapsed: 0.23s, accuracy: 96.68
# Epoch 21:	########################################	elapsed: 0.23s, accuracy: 96.69
# Epoch 22:	########################################	elapsed: 0.24s, accuracy: 96.74
# Epoch 23:	########################################	elapsed: 0.23s, accuracy: 96.76
# Epoch 24:	########################################	elapsed: 0.24s, accuracy: 96.78
# Epoch 25:	########################################	elapsed: 0.24s, accuracy: 96.78
# Epoch 26:	########################################	elapsed: 0.24s, accuracy: 96.81
# Epoch 27:	########################################	elapsed: 0.24s, accuracy: 96.81
# Epoch 28:	########################################	elapsed: 0.25s, accuracy: 96.80
# Epoch 29:	########################################	elapsed: 0.23s, accuracy: 96.79
# Epoch 30:	########################################	elapsed: 0.25s, accuracy: 96.83
# Epoch 31:	########################################	elapsed: 0.25s, accuracy: 96.85
# Epoch 32:	########################################	elapsed: 0.24s, accuracy: 96.85
# Epoch 33:	########################################	elapsed: 0.24s, accuracy: 96.86
# Epoch 34:	########################################	elapsed: 0.23s, accuracy: 96.86
# Epoch 35:	########################################	elapsed: 0.28s, accuracy: 96.87
# Epoch 36:	########################################	elapsed: 0.25s, accuracy: 96.88
# Epoch 37:	########################################	elapsed: 0.24s, accuracy: 96.90
# Epoch 38:	########################################	elapsed: 0.24s, accuracy: 96.89
# Epoch 39:	########################################	elapsed: 0.26s, accuracy: 96.89
# Epoch 40:	########################################	elapsed: 0.24s, accuracy: 96.90
# Epoch 41:	########################################	elapsed: 0.26s, accuracy: 96.94
# Epoch 42:	########################################	elapsed: 0.23s, accuracy: 96.94
# Epoch 43:	########################################	elapsed: 0.23s, accuracy: 96.95
# Epoch 44:	########################################	elapsed: 0.25s, accuracy: 96.97
# Epoch 45:	########################################	elapsed: 0.23s, accuracy: 96.99
# Epoch 46:	########################################	elapsed: 0.23s, accuracy: 97.03
# Epoch 47:	########################################	elapsed: 0.25s, accuracy: 97.03
# Epoch 48:	########################################	elapsed: 0.25s, accuracy: 97.07
# Epoch 49:	########################################	elapsed: 0.24s, accuracy: 97.10
# Epoch 50:	########################################	elapsed: 0.25s, accuracy: 97.11
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>

# %% [markdown]
# ### Deep neural network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

deep_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in deep_mlp[:-1]
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.30s, accuracy: 10.10
# Epoch 2:	########################################	elapsed: 0.27s, accuracy: 10.10
# Epoch 3:	########################################	elapsed: 0.29s, accuracy: 8.92
# Epoch 4:	########################################	elapsed: 0.28s, accuracy: 8.92
# Epoch 5:	########################################	elapsed: 0.28s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.29s, accuracy: 9.74
# Epoch 7:	########################################	elapsed: 0.29s, accuracy: 9.74
# Epoch 8:	########################################	elapsed: 0.28s, accuracy: 14.94
# Epoch 9:	########################################	elapsed: 0.28s, accuracy: 14.02
# Epoch 10:	########################################	elapsed: 0.29s, accuracy: 13.85
# Epoch 11:	########################################	elapsed: 0.29s, accuracy: 14.54
# Epoch 12:	########################################	elapsed: 0.29s, accuracy: 25.01
# Epoch 13:	########################################	elapsed: 0.29s, accuracy: 29.92
# Epoch 14:	########################################	elapsed: 0.29s, accuracy: 29.64
# Epoch 15:	########################################	elapsed: 0.31s, accuracy: 30.69
# Epoch 16:	########################################	elapsed: 0.30s, accuracy: 32.81
# Epoch 17:	########################################	elapsed: 0.31s, accuracy: 34.88
# Epoch 18:	########################################	elapsed: 0.30s, accuracy: 37.82
# Epoch 19:	########################################	elapsed: 0.31s, accuracy: 39.73
# Epoch 20:	########################################	elapsed: 0.29s, accuracy: 41.20
# Epoch 21:	########################################	elapsed: 0.30s, accuracy: 42.64
# Epoch 22:	########################################	elapsed: 0.31s, accuracy: 44.24
# Epoch 23:	########################################	elapsed: 0.30s, accuracy: 45.87
# Epoch 24:	########################################	elapsed: 0.32s, accuracy: 47.64
# Epoch 25:	########################################	elapsed: 0.30s, accuracy: 49.71
# Epoch 26:	########################################	elapsed: 0.31s, accuracy: 51.50
# Epoch 27:	########################################	elapsed: 0.31s, accuracy: 52.80
# Epoch 28:	########################################	elapsed: 0.33s, accuracy: 54.31
# Epoch 29:	########################################	elapsed: 0.31s, accuracy: 55.31
# Epoch 30:	########################################	elapsed: 0.29s, accuracy: 56.34
# Epoch 31:	########################################	elapsed: 0.31s, accuracy: 57.30
# Epoch 32:	########################################	elapsed: 0.28s, accuracy: 58.05
# Epoch 33:	########################################	elapsed: 0.29s, accuracy: 58.46
# Epoch 34:	########################################	elapsed: 0.30s, accuracy: 59.29
# Epoch 35:	########################################	elapsed: 0.31s, accuracy: 60.45
# Epoch 36:	########################################	elapsed: 0.30s, accuracy: 67.36
# Epoch 37:	########################################	elapsed: 0.30s, accuracy: 78.54
# Epoch 38:	########################################	elapsed: 0.30s, accuracy: 81.68
# Epoch 39:	########################################	elapsed: 0.29s, accuracy: 83.60
# Epoch 40:	########################################	elapsed: 0.28s, accuracy: 84.69
# Epoch 41:	########################################	elapsed: 0.29s, accuracy: 85.34
# Epoch 42:	########################################	elapsed: 0.32s, accuracy: 85.55
# Epoch 43:	########################################	elapsed: 0.30s, accuracy: 85.55
# Epoch 44:	########################################	elapsed: 0.28s, accuracy: 85.16
# Epoch 45:	########################################	elapsed: 0.28s, accuracy: 84.63
# Epoch 46:	########################################	elapsed: 0.29s, accuracy: 84.70
# Epoch 47:	########################################	elapsed: 0.29s, accuracy: 85.50
# Epoch 48:	########################################	elapsed: 0.29s, accuracy: 86.09
# Epoch 49:	########################################	elapsed: 0.30s, accuracy: 86.90
# Epoch 50:	########################################	elapsed: 0.30s, accuracy: 87.79
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.36s, reconstruction error: 31.44
# Epoch 2:	########################################	elapsed: 0.36s, reconstruction error: 24.68
# Epoch 3:	########################################	elapsed: 0.36s, reconstruction error: 21.43
# Epoch 4:	########################################	elapsed: 0.37s, reconstruction error: 19.12
# Epoch 5:	########################################	elapsed: 0.36s, reconstruction error: 17.60
# Epoch 6:	########################################	elapsed: 0.35s, reconstruction error: 15.10
# Epoch 7:	########################################	elapsed: 0.36s, reconstruction error: 13.63
# Epoch 8:	########################################	elapsed: 0.37s, reconstruction error: 12.52
# Epoch 9:	########################################	elapsed: 0.37s, reconstruction error: 11.83
# Epoch 10:	########################################	elapsed: 0.34s, reconstruction error: 11.29
# Epoch 11:	########################################	elapsed: 0.36s, reconstruction error: 11.01
# Epoch 12:	########################################	elapsed: 0.35s, reconstruction error: 10.93
# Epoch 13:	########################################	elapsed: 0.36s, reconstruction error: 10.57
# Epoch 14:	########################################	elapsed: 0.36s, reconstruction error: 10.29
# Epoch 15:	########################################	elapsed: 0.36s, reconstruction error: 10.13
# Epoch 16:	########################################	elapsed: 0.36s, reconstruction error: 9.92
# Epoch 17:	########################################	elapsed: 0.37s, reconstruction error: 9.99
# Epoch 18:	########################################	elapsed: 0.36s, reconstruction error: 9.96
# Epoch 19:	########################################	elapsed: 0.34s, reconstruction error: 9.88
# Epoch 20:	########################################	elapsed: 0.37s, reconstruction error: 9.50
# Epoch 21:	########################################	elapsed: 0.36s, reconstruction error: 9.53
# Epoch 22:	########################################	elapsed: 0.38s, reconstruction error: 9.55
# Epoch 23:	########################################	elapsed: 0.38s, reconstruction error: 9.42
# Epoch 24:	########################################	elapsed: 0.34s, reconstruction error: 9.41
# Epoch 25:	########################################	elapsed: 0.33s, reconstruction error: 9.34
# Epoch 26:	########################################	elapsed: 0.36s, reconstruction error: 9.22
# Epoch 27:	########################################	elapsed: 0.38s, reconstruction error: 9.27
# Epoch 28:	########################################	elapsed: 0.36s, reconstruction error: 9.14
# Epoch 29:	########################################	elapsed: 0.36s, reconstruction error: 9.21
# Epoch 30:	########################################	elapsed: 0.37s, reconstruction error: 9.00
# Epoch 31:	########################################	elapsed: 0.36s, reconstruction error: 9.05
# Epoch 32:	########################################	elapsed: 0.37s, reconstruction error: 8.92
# Epoch 33:	########################################	elapsed: 0.36s, reconstruction error: 8.88
# Epoch 34:	########################################	elapsed: 0.35s, reconstruction error: 9.01
# Epoch 35:	########################################	elapsed: 0.36s, reconstruction error: 8.86
# Epoch 36:	########################################	elapsed: 0.35s, reconstruction error: 8.89
# Epoch 37:	########################################	elapsed: 0.36s, reconstruction error: 8.87
# Epoch 38:	########################################	elapsed: 0.36s, reconstruction error: 8.79
# Epoch 39:	########################################	elapsed: 0.36s, reconstruction error: 8.83
# Epoch 40:	########################################	elapsed: 0.36s, reconstruction error: 8.77
# Epoch 41:	########################################	elapsed: 0.35s, reconstruction error: 8.74
# Epoch 42:	########################################	elapsed: 0.37s, reconstruction error: 8.75
# Epoch 43:	########################################	elapsed: 0.35s, reconstruction error: 8.65
# Epoch 44:	########################################	elapsed: 0.35s, reconstruction error: 8.80
# Epoch 45:	########################################	elapsed: 0.38s, reconstruction error: 8.67
# Epoch 46:	########################################	elapsed: 0.36s, reconstruction error: 8.56
# Epoch 47:	########################################	elapsed: 0.37s, reconstruction error: 8.71
# Epoch 48:	########################################	elapsed: 0.35s, reconstruction error: 8.55
# Epoch 49:	########################################	elapsed: 0.36s, reconstruction error: 8.60
# Epoch 50:	########################################	elapsed: 0.35s, reconstruction error: 8.65
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.23s, reconstruction error: 19.11
# Epoch 2:	########################################	elapsed: 0.22s, reconstruction error: 14.84
# Epoch 3:	########################################	elapsed: 0.22s, reconstruction error: 12.79
# Epoch 4:	########################################	elapsed: 0.22s, reconstruction error: 11.48
# Epoch 5:	########################################	elapsed: 0.24s, reconstruction error: 10.28
# Epoch 6:	########################################	elapsed: 0.22s, reconstruction error: 8.35
# Epoch 7:	########################################	elapsed: 0.21s, reconstruction error: 7.15
# Epoch 8:	########################################	elapsed: 0.22s, reconstruction error: 6.66
# Epoch 9:	########################################	elapsed: 0.20s, reconstruction error: 6.11
# Epoch 10:	########################################	elapsed: 0.21s, reconstruction error: 5.82
# Epoch 11:	########################################	elapsed: 0.21s, reconstruction error: 5.58
# Epoch 12:	########################################	elapsed: 0.22s, reconstruction error: 5.41
# Epoch 13:	########################################	elapsed: 0.21s, reconstruction error: 5.19
# Epoch 14:	########################################	elapsed: 0.22s, reconstruction error: 5.07
# Epoch 15:	########################################	elapsed: 0.23s, reconstruction error: 4.97
# Epoch 16:	########################################	elapsed: 0.22s, reconstruction error: 4.99
# Epoch 17:	########################################	elapsed: 0.22s, reconstruction error: 4.81
# Epoch 18:	########################################	elapsed: 0.22s, reconstruction error: 4.81
# Epoch 19:	########################################	elapsed: 0.23s, reconstruction error: 4.64
# Epoch 20:	########################################	elapsed: 0.21s, reconstruction error: 4.54
# Epoch 21:	########################################	elapsed: 0.23s, reconstruction error: 4.61
# Epoch 22:	########################################	elapsed: 0.22s, reconstruction error: 4.53
# Epoch 23:	########################################	elapsed: 0.22s, reconstruction error: 4.48
# Epoch 24:	########################################	elapsed: 0.22s, reconstruction error: 4.41
# Epoch 25:	########################################	elapsed: 0.21s, reconstruction error: 4.48
# Epoch 26:	########################################	elapsed: 0.22s, reconstruction error: 4.44
# Epoch 27:	########################################	elapsed: 0.23s, reconstruction error: 4.44
# Epoch 28:	########################################	elapsed: 0.22s, reconstruction error: 4.36
# Epoch 29:	########################################	elapsed: 0.23s, reconstruction error: 4.30
# Epoch 30:	########################################	elapsed: 0.22s, reconstruction error: 4.36
# Epoch 31:	########################################	elapsed: 0.23s, reconstruction error: 4.23
# Epoch 32:	########################################	elapsed: 0.21s, reconstruction error: 4.22
# Epoch 33:	########################################	elapsed: 0.23s, reconstruction error: 4.22
# Epoch 34:	########################################	elapsed: 0.22s, reconstruction error: 4.19
# Epoch 35:	########################################	elapsed: 0.22s, reconstruction error: 4.26
# Epoch 36:	########################################	elapsed: 0.23s, reconstruction error: 4.18
# Epoch 37:	########################################	elapsed: 0.21s, reconstruction error: 4.14
# Epoch 38:	########################################	elapsed: 0.22s, reconstruction error: 4.21
# Epoch 39:	########################################	elapsed: 0.21s, reconstruction error: 4.19
# Epoch 40:	########################################	elapsed: 0.23s, reconstruction error: 4.15
# Epoch 41:	########################################	elapsed: 0.23s, reconstruction error: 4.13
# Epoch 42:	########################################	elapsed: 0.22s, reconstruction error: 4.21
# Epoch 43:	########################################	elapsed: 0.22s, reconstruction error: 4.10
# Epoch 44:	########################################	elapsed: 0.22s, reconstruction error: 4.14
# Epoch 45:	########################################	elapsed: 0.22s, reconstruction error: 4.02
# Epoch 46:	########################################	elapsed: 0.23s, reconstruction error: 4.08
# Epoch 47:	########################################	elapsed: 0.21s, reconstruction error: 4.12
# Epoch 48:	########################################	elapsed: 0.21s, reconstruction error: 4.05
# Epoch 49:	########################################	elapsed: 0.22s, reconstruction error: 3.97
# Epoch 50:	########################################	elapsed: 0.23s, reconstruction error: 4.08
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.24s, reconstruction error: 15.21
# Epoch 2:	########################################	elapsed: 0.25s, reconstruction error: 10.99
# Epoch 3:	########################################	elapsed: 0.29s, reconstruction error: 9.05
# Epoch 4:	########################################	elapsed: 0.29s, reconstruction error: 8.00
# Epoch 5:	########################################	elapsed: 0.28s, reconstruction error: 7.21
# Epoch 6:	########################################	elapsed: 0.28s, reconstruction error: 5.67
# Epoch 7:	########################################	elapsed: 0.28s, reconstruction error: 4.94
# Epoch 8:	########################################	elapsed: 0.28s, reconstruction error: 4.45
# Epoch 9:	########################################	elapsed: 0.26s, reconstruction error: 4.17
# Epoch 10:	########################################	elapsed: 0.24s, reconstruction error: 3.98
# Epoch 11:	########################################	elapsed: 0.25s, reconstruction error: 3.80
# Epoch 12:	########################################	elapsed: 0.25s, reconstruction error: 3.66
# Epoch 13:	########################################	elapsed: 0.25s, reconstruction error: 3.64
# Epoch 14:	########################################	elapsed: 0.24s, reconstruction error: 3.58
# Epoch 15:	########################################	elapsed: 0.24s, reconstruction error: 3.53
# Epoch 16:	########################################	elapsed: 0.25s, reconstruction error: 3.52
# Epoch 17:	########################################	elapsed: 0.26s, reconstruction error: 3.44
# Epoch 18:	########################################	elapsed: 0.23s, reconstruction error: 3.34
# Epoch 19:	########################################	elapsed: 0.25s, reconstruction error: 3.32
# Epoch 20:	########################################	elapsed: 0.22s, reconstruction error: 3.31
# Epoch 21:	########################################	elapsed: 0.24s, reconstruction error: 3.24
# Epoch 22:	########################################	elapsed: 0.25s, reconstruction error: 3.27
# Epoch 23:	########################################	elapsed: 0.24s, reconstruction error: 3.19
# Epoch 24:	########################################	elapsed: 0.23s, reconstruction error: 3.11
# Epoch 25:	########################################	elapsed: 0.24s, reconstruction error: 3.11
# Epoch 26:	########################################	elapsed: 0.24s, reconstruction error: 3.14
# Epoch 27:	########################################	elapsed: 0.24s, reconstruction error: 3.03
# Epoch 28:	########################################	elapsed: 0.23s, reconstruction error: 3.11
# Epoch 29:	########################################	elapsed: 0.25s, reconstruction error: 3.13
# Epoch 30:	########################################	elapsed: 0.24s, reconstruction error: 3.12
# Epoch 31:	########################################	elapsed: 0.23s, reconstruction error: 3.10
# Epoch 32:	########################################	elapsed: 0.24s, reconstruction error: 2.99
# Epoch 33:	########################################	elapsed: 0.22s, reconstruction error: 3.03
# Epoch 34:	########################################	elapsed: 0.22s, reconstruction error: 3.02
# Epoch 35:	########################################	elapsed: 0.24s, reconstruction error: 3.01
# Epoch 36:	########################################	elapsed: 0.23s, reconstruction error: 3.07
# Epoch 37:	########################################	elapsed: 0.23s, reconstruction error: 2.98
# Epoch 38:	########################################	elapsed: 0.24s, reconstruction error: 3.02
# Epoch 39:	########################################	elapsed: 0.23s, reconstruction error: 2.93
# Epoch 40:	########################################	elapsed: 0.23s, reconstruction error: 3.00
# Epoch 41:	########################################	elapsed: 0.22s, reconstruction error: 2.94
# Epoch 42:	########################################	elapsed: 0.23s, reconstruction error: 2.99
# Epoch 43:	########################################	elapsed: 0.23s, reconstruction error: 2.96
# Epoch 44:	########################################	elapsed: 0.24s, reconstruction error: 2.93
# Epoch 45:	########################################	elapsed: 0.25s, reconstruction error: 2.99
# Epoch 46:	########################################	elapsed: 0.23s, reconstruction error: 2.95
# Epoch 47:	########################################	elapsed: 0.24s, reconstruction error: 2.87
# Epoch 48:	########################################	elapsed: 0.24s, reconstruction error: 2.95
# Epoch 49:	########################################	elapsed: 0.25s, reconstruction error: 2.98
# Epoch 50:	########################################	elapsed: 0.24s, reconstruction error: 2.89
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.31s, accuracy: 94.09
# Epoch 2:	########################################	elapsed: 0.30s, accuracy: 95.21
# Epoch 3:	########################################	elapsed: 0.29s, accuracy: 95.66
# Epoch 4:	########################################	elapsed: 0.32s, accuracy: 95.92
# Epoch 5:	########################################	elapsed: 0.31s, accuracy: 96.17
# Epoch 6:	########################################	elapsed: 0.34s, accuracy: 96.37
# Epoch 7:	########################################	elapsed: 0.37s, accuracy: 96.45
# Epoch 8:	########################################	elapsed: 0.37s, accuracy: 96.51
# Epoch 9:	########################################	elapsed: 0.38s, accuracy: 96.57
# Epoch 10:	########################################	elapsed: 0.37s, accuracy: 96.69
# Epoch 11:	########################################	elapsed: 0.31s, accuracy: 96.72
# Epoch 12:	########################################	elapsed: 0.38s, accuracy: 96.75
# Epoch 13:	########################################	elapsed: 0.31s, accuracy: 96.79
# Epoch 14:	########################################	elapsed: 0.36s, accuracy: 96.81
# Epoch 15:	########################################	elapsed: 0.56s, accuracy: 96.83
# Epoch 16:	########################################	elapsed: 0.55s, accuracy: 96.85
# Epoch 17:	########################################	elapsed: 0.42s, accuracy: 96.90
# Epoch 18:	########################################	elapsed: 0.57s, accuracy: 96.89
# Epoch 19:	########################################	elapsed: 0.50s, accuracy: 96.91
# Epoch 20:	########################################	elapsed: 0.41s, accuracy: 96.92
# Epoch 21:	########################################	elapsed: 0.36s, accuracy: 96.95
# Epoch 22:	########################################	elapsed: 0.30s, accuracy: 96.97
# Epoch 23:	########################################	elapsed: 0.30s, accuracy: 96.98
# Epoch 24:	########################################	elapsed: 0.30s, accuracy: 97.00
# Epoch 25:	########################################	elapsed: 0.37s, accuracy: 97.00
# Epoch 26:	########################################	elapsed: 0.35s, accuracy: 97.03
# Epoch 27:	########################################	elapsed: 0.32s, accuracy: 97.05
# Epoch 28:	########################################	elapsed: 0.34s, accuracy: 97.06
# Epoch 29:	########################################	elapsed: 0.36s, accuracy: 97.05
# Epoch 30:	########################################	elapsed: 0.34s, accuracy: 97.05
# Epoch 31:	########################################	elapsed: 0.28s, accuracy: 97.08
# Epoch 32:	########################################	elapsed: 0.30s, accuracy: 97.07
# Epoch 33:	########################################	elapsed: 0.39s, accuracy: 97.09
# Epoch 34:	########################################	elapsed: 0.29s, accuracy: 97.09
# Epoch 35:	########################################	elapsed: 0.28s, accuracy: 97.11
# Epoch 36:	########################################	elapsed: 0.27s, accuracy: 97.11
# Epoch 37:	########################################	elapsed: 0.31s, accuracy: 97.09
# Epoch 38:	########################################	elapsed: 0.34s, accuracy: 97.08
# Epoch 39:	########################################	elapsed: 0.38s, accuracy: 97.08
# Epoch 40:	########################################	elapsed: 0.33s, accuracy: 97.10
# Epoch 41:	########################################	elapsed: 0.34s, accuracy: 97.12
# Epoch 42:	########################################	elapsed: 0.40s, accuracy: 97.12
# Epoch 43:	########################################	elapsed: 0.41s, accuracy: 97.12
# Epoch 44:	########################################	elapsed: 0.28s, accuracy: 97.12
# Epoch 45:	########################################	elapsed: 0.37s, accuracy: 97.13
# Epoch 46:	########################################	elapsed: 0.33s, accuracy: 97.13
# Epoch 47:	########################################	elapsed: 0.28s, accuracy: 97.14
# Epoch 48:	########################################	elapsed: 0.31s, accuracy: 97.14
# Epoch 49:	########################################	elapsed: 0.34s, accuracy: 97.15
# Epoch 50:	########################################	elapsed: 0.37s, accuracy: 97.15
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
